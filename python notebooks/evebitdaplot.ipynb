# %%
import pandas as pd
import matplotlib.pyplot as plt
import plotly.express as px
from tqdm import tqdm
import time

# Simulate a time-consuming task with tqdm loader
def load_data_with_progress(file_path):
    for _ in tqdm(range(100), desc="Loading data"):
        time.sleep(0.05)  # Simulating the loading time
    return pd.read_excel(file_path)
    
# Load the data from the uploaded Excel file
file_path = 'sp500_ev_ebitda.xlsx'
data = pd.read_excel(file_path)

# Display the first few rows of the dataframe to understand its structure
print(data.to_string())

# Load the data from the uploaded Excel file
file_path = 'sp500_ev_ebitda.xlsx'
data = pd.read_excel(file_path)

# Create the interactive scatter plot
fig = px.scatter(data, x='Ticker', y='EV/EBITDA', title='EV/EBITDA Values of S&P 500 Companies')
fig.update_layout(xaxis={'tickangle': 90, 'tickfont': {'size': 8}}, yaxis_title='EV/EBITDA', xaxis_title='Ticker')
fig.show()

# Sort the data by EV/EBITDA
sorted_data = data.sort_values(by='EV/EBITDA')

# Create a static scatter plot with sorted data using matplotlib
plt.figure(figsize=(120, 80))
plt.scatter(sorted_data['Ticker'], sorted_data['EV/EBITDA'], color='blue', alpha=0.7)
plt.title('EV/EBITDA Values of S&P 500 Companies (Sorted)')
plt.xlabel('Ticker')
plt.ylabel('EV/EBITDA')
plt.xticks(rotation=90, fontsize=8)
plt.grid(True)

# Create a scatter plot with company ticker on the graph and x-axis
plt.figure(figsize=(12, 8))
plt.scatter(df_sorted['Ticker'], df_sorted['EV/EBITDA'], color='blue', alpha=0.6)
plt.title('EV/EBITDA Ratio of S&P 500 Companies')
plt.xlabel('Company Ticker')
plt.ylabel('EV/EBITDA Ratio')

# Add labels to each point
for i, txt in enumerate(df_sorted['Ticker']):
    plt.annotate(txt, (df_sorted['Ticker'].iloc[i], df_sorted['EV/EBITDA'].iloc[i]), fontsize=8, rotation=45, ha='right')

plt.xticks(rotation=90, fontsize=8)
plt.grid(True)
plt.tight_layout()

# Display the plot
plt.show()


# Display the saved sorted plot image
sorted_output_path
# Out:
#     Ticker                                 Company   EV/EBITDA
# 0      MMM                                      3M    8.276278
# 1      AOS                             A. O. Smith   14.313191
# 2      ABT                                  Abbott   18.553022
# 3     ABBV                                  AbbVie   13.496173
# 4      ACN                               Accenture   16.302891
# 5     ADBE                              Adobe Inc.   26.953633
# 6      AMD                  Advanced Micro Devices   66.169469
# 7      AES                         AES Corporation   13.805961
# 8      AFL                                   Aflac    8.396937
# 9        A                    Agilent Technologies   24.565465
# 10     APD              Air Products and Chemicals   18.356741
# 11    ABNB                                  Airbnb   51.263673
# 12    AKAM                                  Akamai   14.908880
# 13     ALB                   Albemarle Corporation  -55.216419
# ...

# %%
# Create a scatter plot with company ticker on the graph and x-axis
plt.figure(figsize=(12, 8))
plt.scatter(df_sorted['Ticker'], df_sorted['EV/EBITDA'], color='blue', alpha=0.6)
plt.title('EV/EBITDA Ratio of S&P 500 Companies')
plt.xlabel('Company Ticker')
plt.ylabel('EV/EBITDA Ratio')

# Add labels to each point
for i, txt in enumerate(df_sorted['Ticker']):
    plt.annotate(txt, (df_sorted['Ticker'].iloc[i], df_sorted['EV/EBITDA'].iloc[i]), fontsize=8, rotation=45, ha='right')

plt.xticks(rotation=90, fontsize=8)
plt.grid(True)
plt.tight_layout()

# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 3
#       1 # Create a scatter plot with company ticker on the graph and x-axis
#       2 plt.figure(figsize=(12, 8))
# ----> 3 plt.scatter(df_sorted['Ticker'], df_sorted['EV/EBITDA'], color='blue', alpha=0.6)
#       4 plt.title('EV/EBITDA Ratio of S&P 500 Companies')
#       5 plt.xlabel('Company Ticker')
#
# NameError: name 'df_sorted' is not defined
